# %% [markdown]
# ## Practice
# You have an image (from your choice)
#
# Your goal is **to detect the most meaningful edges** in the image.
# You may use:
# - Sobel filtering
# - Canny edge detection
# - thresholding
# - Gaussian blur or other preprocessing
# But you must **decide the parameters** yourself.

# %% [markdown]
# ### Requirements
# The program should:
# - Load the image and Convert it to GrayScale using the OpenCV like we did in the first session
# - Apply at least **2 different edge detection techniques**
# - Experiment with different parameters
# - Display and compare the results

# %% [markdown]
# ## The challenge
# Answer these questions by showing the code of each question

# %% [markdown]
# ### 1.Which edge detection method worked best?

# %%
# ! The code for sobel and canny and which one is good

# %% [markdown]
# ### 2.How do different Canny thresholds change the result?

# %%
#! Try several combinations like : (30,100), (50,150), (100,200) and see the results. Try to Explain which one gives the best edges.

# %% [markdown]
# ### 3.Does applying blur before edge detection improve the result?

# %%
import cv2
#! Example
blur = cv2.GaussianBlur(gray,(5,5),0)
#* contune with the rest of the code and see the results

# %% [markdown]
# ### 4.What type of image makes edge detection difficult?
# Example : low contrast, low contrast .....

# %%
#! Show the results here
